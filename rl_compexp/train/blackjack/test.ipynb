# %%
import numpy as np

obs = np.load("/root/gym/rl_compexp/save/Blackjack-DQN64/observations.npy")
act = np.load("/root/gym/rl_compexp/save/Blackjack-DQN64/actions.npy")
hidden_outputs = np.load(
    "/root/gym/rl_compexp/save/Blackjack-DQN64/hidden_outputs.npy"
)
hidden_outputs = np.squeeze(hidden_outputs, axis=1)
print(obs.shape, act.shape, hidden_outputs.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
# ----> 3 obs = np.load("/root/gym/rl_compexp/save/Blackjack-DQN64/observations.npy")
#       4 act = np.load("/root/gym/rl_compexp/save/Blackjack-DQN64/actions.npy")
#       5 hidden_outputs = np.load(
#       6     "/root/gym/rl_compexp/save/Blackjack-DQN64/hidden_outputs.npy"
#       7 )
#
# File ~/miniconda3/lib/python3.12/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/root/gym/rl_compexp/save/Blackjack-DQN64/observations.npy'

# %%
np.save("/root/gym/rl_compexp/save/Blackjack-DQN64/hidden_outputs.npy", hidden_outputs)
